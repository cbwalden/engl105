# %% [markdown]
# ## County Health Data ReadMe

# %% [markdown]
# ##### The purpose of this file is to outline how to use the County Health Data and explain how these steps can be reproduced.

# %% [markdown]
# Import the Pandas and Numpy packages in order to use and manipulate the data from the .csv file.
#
# Pandas and Numpy can be imported using the following command:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Once the information above has been typed, select the shift and return button on the keyboard. Utilizing these two buttons runs the code.
#
# Pandas is abbreviated to "pd" so "pandas" does not have to be written everytime it needs to be utilized. The same situation occurs with Numpy, which is abbreviated to "np".

# %% [markdown]
# After Pandas and Numpy have been imported, the .csv file containing the data must be read. This is necessary in order to utilize the data. The CountyHealthData_2014-2015.csv will be read using Pandas (pd) and be defined as "df". Defining this removes the requirement of inserting the full name of the file everytime.
#
# CountyHealthData_2014-2015.csv can be defined using the following command:

# %%
df=pd.read_csv("CountyHealthData_2014-2015.csv")

# %%
Object1="Monday"
Object2="Tuesday"
Object3="Wednesday"
Object4="Thursday"
Object5="Friday"
WeekDays=(Object1, Object2, Object3, Object4, Object5)

# %%
print(WeekDays)
# Out:
# ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday')

# %% [markdown]
# **Bolded text**

# %% [markdown]
# *Italics*

# %%
df.shape
# Out:
# (6109, 64)

# %%
df.size
# Out:
# 390976

# %%
df.size == 6109*64
# Out:
# True

# %%
df.columns
# Out:
# Index(['State', 'Region', 'Division', 'County', 'FIPS', 'GEOID', 'SMS Region',
#        'Year', 'Premature death', 'Poor or fair health',
#        'Poor physical health days', 'Poor mental health days',
#        'Low birthweight', 'Adult smoking', 'Adult obesity',
#        'Food environment index', 'Physical inactivity',
#        'Access to exercise opportunities', 'Excessive drinking',
#        'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
#        'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
#        'Mental health providers', 'Preventable hospital stays',
#        'Diabetic screening', 'Mammography screening', 'High school graduation',
#        'Some college', 'Unemployment', 'Children in poverty',
#        'Income inequality', 'Children in single-parent households',
#        'Social associations', 'Violent crime', 'Injury deaths',
#        'Air pollution - particulate matter', 'Drinking water violations',
# ...

# %%
df.dtypes
# Out:
# State                                object
# Region                               object
# Division                             object
# County                               object
# FIPS                                  int64
#                                      ...
# Other primary care providers        float64
# Median household income               int64
# Children eligible for free lunch    float64
# Homicide rate                       float64
# Inadequate social support           float64
# Length: 64, dtype: object

# %%
df.State.value_counts()
# Out:
# TX    469
# GA    318
# VA    266
# KY    240
# MO    229
# IL    204
# NC    200
# KS    199
# IA    198
# TN    190
# IN    184
# OH    176
# MN    174
# MI    164
# MS    163
# NE    157
# OK    154
# AR    150
# WI    144
# FL    134
# PA    134
# AL    134
# LA    128
# NY    124
# CO    119
# SD    117
# CA    114
# WV    110
# ND     92
# MT     92
# SC     92
# ID     84
# WA     78
# OR     67
# NM     64
# UT     54
# MD     48
# AK     46
# WY     46
# NJ     42
# NV     32
# ME     32
# AZ     30
# MA     28
# VT     28
# NH     20
# CT     16
# RI     10
# HI      8
# DE      6
# DC      1
# Name: State, dtype: int64

# %%
print(df.Region.dtypes)
# Out:
# object

# %%
df.Region.value_counts()
# Out:
# South        2803
# Midwest      2038
# West          834
# Northeast     434
# Name: Region, dtype: int64

# %%
df.sample(n=10)
# Out:
#      State     Region            Division              County   FIPS  GEOID  \
# 132     AL      South  East South Central        Macon County   1087   1087
# 142     AL      South  East South Central       Mobile County   1097   1097
# 4693    SD    Midwest  West North Central        Moody County  46101  46101
# 135     AL      South  East South Central      Madison County   1089   1089
# 2688    MN    Midwest  West North Central     Nicollet County  27103  27103
# 1514    IL    Midwest  East North Central     Randolph County  17157  17157
# 1005    GA      South      South Atlantic      Stewart County  13259  13259
# 1361    IL    Midwest  East North Central    Alexander County  17003  17003
# 1367    IL    Midwest  East North Central        Brown County  17009  17009
# 3940    NY  Northeast        Mid-Atlantic  Schenectady County  36093  36093
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# ...

# %%
df.County.value_counts()
# Out:
# Washington County       60
# Jefferson County        50
# Franklin County         48
# Lincoln County          46
# Jackson County          44
#                         ..
# Dickens County           1
# Issaquena County         1
# District of Columbia     1
# Golden Valley County     1
# Aurora County            1
# Name: County, Length: 1830, dtype: int64

# %%
df["State"][5:10]
# Out:
# 5    AK
# 6    AK
# 7    AK
# 8    AK
# 9    AK
# Name: State, dtype: object

# %%
df[["State","Year","County","Uninsured adults"]][19:25]
# Out:
#    State      Year                      County  Uninsured adults
# 19    AK  1/1/2015       Kodiak Island Borough             0.320
# 20    AK  1/1/2014  Lake and Peninsula Borough             0.434
# 21    AK  1/1/2015  Lake and Peninsula Borough             0.406
# 22    AK  1/1/2014   Matanuska-Susitna Borough             0.266
# 23    AK  1/1/2015   Matanuska-Susitna Borough             0.254
# 24    AK  1/1/2014            Nome Census Area             0.373

# %%
df.iloc[5010,55]
# Out:
# 0.281

# %%
df.iloc[:,3]
# Out:
# 0       Aleutians West Census Area
# 1       Aleutians West Census Area
# 2                Anchorage Borough
# 3                Anchorage Borough
# 4               Bethel Census Area
#                    ...
# 6104                  Uinta County
# 6105               Washakie County
# 6106               Washakie County
# 6107                 Weston County
# 6108                 Weston County
# Name: County, Length: 6109, dtype: object

# %%
df.iloc[0:3,:]
# Out:
#   State Region Division                      County  FIPS  GEOID   SMS Region  \
# 0    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 1    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 2    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
#
#        Year  Premature death  Poor or fair health  ...  Drug poisoning deaths  \
# 0  1/1/2014              NaN                0.122  ...                    NaN
# 1  1/1/2015              NaN                0.122  ...                    NaN
# 2  1/1/2014           6827.0                0.125  ...                  15.37
#
#    Uninsured adults  Uninsured children  Health care costs  \
# 0             0.374               0.250             3791.0
# 1             0.314               0.176             4837.0
# 2             0.218               0.096             6588.0
#
#    Could not see doctor due to cost  Other primary care providers  \
# ...

# %%
df.loc[0:3,"State"]
# Out:
# 0    AK
# 1    AK
# 2    AK
# 3    AK
# Name: State, dtype: object

# %%
df.loc[0:3,["State","County","Division"]]
# Out:
#   State                      County Division
# 0    AK  Aleutians West Census Area  Pacific
# 1    AK  Aleutians West Census Area  Pacific
# 2    AK           Anchorage Borough  Pacific
# 3    AK           Anchorage Borough  Pacific

# %%
df[df["State"] == "RI"]
# Out:
#      State     Region     Division             County   FIPS  GEOID  \
# 4505    RI  Northeast  New England     Bristol County  44001  44001
# 4506    RI  Northeast  New England     Bristol County  44001  44001
# 4507    RI  Northeast  New England        Kent County  44003  44003
# 4508    RI  Northeast  New England        Kent County  44003  44003
# 4509    RI  Northeast  New England     Newport County  44005  44005
# 4510    RI  Northeast  New England     Newport County  44005  44005
# 4511    RI  Northeast  New England  Providence County  44007  44007
# 4512    RI  Northeast  New England  Providence County  44007  44007
# 4513    RI  Northeast  New England  Washington County  44009  44009
# 4514    RI  Northeast  New England  Washington County  44009  44009
#
#      SMS Region      Year  Premature death  Poor or fair health  ...  \
# 4505  Region 12  1/1/2014           4543.0                0.087  ...
# 4506  Region 12  1/1/2015           3891.0                0.087  ...
# ...

# %%
RI_subset = df[df["State"] == "RI"].copy()

# %%
RI_subset
# Out:
#      State     Region     Division             County   FIPS  GEOID  \
# 4505    RI  Northeast  New England     Bristol County  44001  44001
# 4506    RI  Northeast  New England     Bristol County  44001  44001
# 4507    RI  Northeast  New England        Kent County  44003  44003
# 4508    RI  Northeast  New England        Kent County  44003  44003
# 4509    RI  Northeast  New England     Newport County  44005  44005
# 4510    RI  Northeast  New England     Newport County  44005  44005
# 4511    RI  Northeast  New England  Providence County  44007  44007
# 4512    RI  Northeast  New England  Providence County  44007  44007
# 4513    RI  Northeast  New England  Washington County  44009  44009
# 4514    RI  Northeast  New England  Washington County  44009  44009
#
#      SMS Region      Year  Premature death  Poor or fair health  ...  \
# 4505  Region 12  1/1/2014           4543.0                0.087  ...
# 4506  Region 12  1/1/2015           3891.0                0.087  ...
# ...

# %%
df[df["State"] == "NC"].copy()
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...
